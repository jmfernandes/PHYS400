# %%
a = rand(100)

# %%
x = range(len(a))

# %%
scatter(x,a)
# Out:
# &lt;matplotlib.collections.PathCollection at 0x5f7a710&gt;

# %%
plot(a)
# Out:
# [&lt;matplotlib.lines.Line2D at 0x6ba4050&gt;]
